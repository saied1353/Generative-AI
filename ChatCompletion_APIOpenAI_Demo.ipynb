# %%
from google.colab import userdata
ΟΡΕΝΑΙ_API_KEY = userdata.get('ΟΡΕΝΑΙ_API_KEY')

# %%
import openai

# %%
# !pip install openai==0.28

# %%
# !pip show openai

# %%
openai.api_key = ΟΡΕΝΑΙ_API_KEY

# %%
import openai
openai.api_base = "https://openrouter.ai/api/v1"

openai.api_key = "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"

print(openai.Model.list())

# %%
import pandas as pd
pd.DataFrame(openai.Model.list()["data"])

# %% [markdown]
# # ChatCompletion API and Completion API
#
# - Completion API: Hooks you up with text completions from a single prompt.
#
# - Chat Completion API: Nails it in the chat game, keeping the conversational flow intact

# %% [markdown]
# # ChatCompletion API

# %%
prompt = "Hello, How are you?"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ]
)
print(response)

# %%
prompt = "Hello, How are you?"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ]
)
print(response["choices"][0]['message']['content'])

# %%
# ChatCompletion API

prompt1 = "Hello How are you?"
prompt2 = "I am 25 years old & I am a Programmer"
prompt3 = "Tell me about me"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt1},
        {"role": "user", "content": prompt2},
        {"role": "user", "content": prompt3},
    ]
)

print(response["choices"][0]["message"]["content"])

# %%
prompt = "What is Python?"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    max_tokens = 25
)

print(response["choices"][0]['message']['content'])

# %%
# ChatCompletion API

prompt = "What is Python?"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.7
)

print(response["choices"][0]["message"]["content"])

# %%
# ChatCompletion API

prompt = "What is Python?"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6,
    n = 2
)

print(response)

# %%
# ChatCompletion API

prompt = "Give me the sentiment of this sentence: This Movie is Amazing!"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6,
)

print(response["choices"][0]["message"]["content"])

# %%
# ChatCompletion API

prompt = "Give me bengali transilation of this sentence: This Movie is Amazing!"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6,
)

print(response["choices"][0]["message"]["content"])

# %%
# ChatCompletion API

prompt = "Detect the language of this sentence: This Movie is Amazing!"

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6,
)

print(response["choices"][0]["message"]["content"])

# %%
# ChatCompletion API

prompt = "Give me a Python code for fibonacci "

response =openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.6,
)

print(response["choices"][0]["message"]["content"])
